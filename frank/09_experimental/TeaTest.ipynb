# %%
import numpy as np
import random
from scipy import stats
random.seed(42)

A = np.random.normal(23, 5, 10000)
B = np.random.normal(23, 5, 100000)

stats.ttest_ind(A, B)
stats.ttest_ind(A,A)
# Out:
# TtestResult(statistic=np.float64(0.0), pvalue=np.float64(1.0), df=np.float64(19998.0))
