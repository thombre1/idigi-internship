# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#generally importing everything is not recommended
from pylab import *

# target mean, spread (standard deviation), number of values
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.2, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)
plt.show()

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %%
r_value ** 2
# Out:
# np.float64(0.9893557353108046)

# %%
import matplotlib.pyplot as plt
def predict(x):
    return slope * x + intercept

fitline = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitline, c='b')
plt.show()
